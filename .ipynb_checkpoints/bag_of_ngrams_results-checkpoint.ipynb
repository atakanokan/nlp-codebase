# %%
import pandas as pd

# %%
import pickle as pkl

# %%
results_list = ["param_val_losses_adam_lemma.p",
                "param_val_losses_adam_lemma.p copy",
                "param_val_losses_adam_lemma.p copy 2",
                "param_val_losses_adam_lemma.p copy 3"]
opt_lemma_list = ["adam_lemma",
                "adam_nolemma",
                "sgd_lemma",
                "sgd_nolemma"]

# %%
column_list = ["optimizer","lemmatization","learning rate","n-gram",
               "vocab_size","embedding_size","batch_size",
               list(range(0,40))]

# %%
results = pkl.load(open(results_list[0],"rb"))
print(results)
# Out:
# {(0.01, 1, 100000.0, 100, 128): [62.9, 72.06, 77.42, 82.44, 84.56, 84.48, 86.06, 86.4, 86.58, 87.14, 86.56, 87.34, 87.3, 87.66, 87.68, 87.76, 87.06, 87.54, 87.38, 87.38, 87.34, 87.04, 87.24, 87.44, 87.22, 87.34, 87.06, 86.78, 87.1, 87.1], (0.01, 2, 100000.0, 100, 128): [66.06, 72.84, 80.14, 83.22, 84.26, 85.88, 86.28, 86.36, 86.92, 87.28, 87.4, 87.26, 87.6, 87.56, 87.28, 87.28, 87.44, 87.52, 87.32, 87.22, 87.12, 87.14, 87.1, 87.02, 86.8, 87.0, 87.12, 87.32, 86.94, 86.84], (0.01, 3, 100000.0, 100, 128): [53.94, 59.26, 78.28, 80.06, 83.74, 84.98, 85.82, 86.48, 86.4, 86.98, 86.6, 86.5, 87.5, 87.52, 87.62, 87.32, 87.16, 87.3, 87.26, 87.24, 87.22, 87.1, 86.74, 86.34, 86.76, 86.3, 86.36, 86.42, 86.3, 86.46], (0.1, 1, 100000.0, 100, 128): [83.84, 81.06, 84.66, 85.14, 85.6, 87.22, 87.28, 86.9, 85.34, 85.34, 86.02, 85.98, 86.2, 84.36, 85.4, 84.82, 84.36, 85.2, 85.24, 84.94, 84.72, 84.64, 84.48, 84.48, 84.68, 84.66, 84.74, 84.12, 84.6, 84.82], (0.1, 2, 100000.0, 100, 128): [81.46, 83.56, 85.6,
# ...

# %%
for key in list(results.keys()):
    print(len(results[key]))
# Out:
# 30
# 30
# 30
# 30
# 30
# 30

# %%
# for i in range(len(results_list)):
    
#     if i == 0:
#         results = pkl.load(open(results_list[i],"rb"))
#     else:
#         results.update(pkl.load(open(results_list[i],"rb")))
        
# print(results)

# %%
results_df = pd.DataFrame.from_dict(results).T
results_df
# Out:
#                             0      1      2      3      4      5      6   \
# 0.01 1 100000.0 100 128  62.90  72.06  77.42  82.44  84.56  84.48  86.06
#      2 100000.0 100 128  66.06  72.84  80.14  83.22  84.26  85.88  86.28
#      3 100000.0 100 128  53.94  59.26  78.28  80.06  83.74  84.98  85.82
# 0.10 1 100000.0 100 128  83.84  81.06  84.66  85.14  85.60  87.22  87.28
#      2 100000.0 100 128  81.46  83.56  85.60  86.24  86.72  87.68  87.16
#      3 100000.0 100 128  82.10  84.56  85.70  85.50  86.16  86.68  86.94
#
#                             7      8      9   ...       20     21     22  \
# 0.01 1 100000.0 100 128  86.40  86.58  87.14  ...    87.34  87.04  87.24
#      2 100000.0 100 128  86.36  86.92  87.28  ...    87.12  87.14  87.10
#      3 100000.0 100 128  86.48  86.40  86.98  ...    87.22  87.10  86.74
# 0.10 1 100000.0 100 128  86.90  85.34  85.34  ...    84.72  84.64  84.48
#      2 100000.0 100 128  87.04  86.08  86.50  ...    85.60  85.28  84.62
# ...

# %%
results_df.reset_index(level=[0,1,2,3,4])
# Out:
#    level_0  level_1   level_2  level_3  level_4      0      1      2      3  \
# 0     0.01        1  100000.0      100      128  62.90  72.06  77.42  82.44
# 1     0.01        2  100000.0      100      128  66.06  72.84  80.14  83.22
# 2     0.01        3  100000.0      100      128  53.94  59.26  78.28  80.06
# 3     0.10        1  100000.0      100      128  83.84  81.06  84.66  85.14
# 4     0.10        2  100000.0      100      128  81.46  83.56  85.60  86.24
# 5     0.10        3  100000.0      100      128  82.10  84.56  85.70  85.50
#
#        4  ...       20     21     22     23     24     25     26     27  \
# 0  84.56  ...    87.34  87.04  87.24  87.44  87.22  87.34  87.06  86.78
# 1  84.26  ...    87.12  87.14  87.10  87.02  86.80  87.00  87.12  87.32
# 2  83.74  ...    87.22  87.10  86.74  86.34  86.76  86.30  86.36  86.42
# 3  85.60  ...    84.72  84.64  84.48  84.48  84.68  84.66  84.74  84.12
# 4  86.72  ...    85.60  85.28  84.62  84.92  85.24  85.48  85.22  84.94
# ...

# %% [markdown]
# ## Plots

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#plt.figure(figsize = (10,5))
results_df.T.plot.line()

# %%
plt.figure(figsize = (10,5))
_ = plt.plot(results_df.T.values)
